# %%
import torch
from torch import nn
from d2l import torch as d2l

# %%
net = nn.Sequential(nn.LazyLinear(256), nn.ReLU(), nn.LazyLinear(10))

# %%
net.state_dict()
# Out:
# OrderedDict([('0.weight', <UninitializedParameter>),
#              ('0.bias', <UninitializedParameter>),
#              ('2.weight', <UninitializedParameter>),
#              ('2.bias', <UninitializedParameter>)])

# %%
X = torch.rand(2, 20)

# %%
net(X)
# Out:
# tensor([[-0.0486,  0.3652, -0.1729,  0.0566, -0.0399, -0.0679,  0.1015, -0.1176,
#          -0.1808,  0.3562],
#         [-0.0413,  0.2680, -0.0960,  0.1048,  0.0513, -0.0832,  0.1218, -0.1503,
#          -0.1816,  0.2890]], grad_fn=<AddmmBackward0>)

# %%
net[0].weight.shape
# Out:
# torch.Size([256, 20])
